# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
sns.set_theme(style="whitegrid")
plt.rcParams["font.size"] = 10

# %%
# 1. Exact fraud cs non fraud counts and pourcentages 
print("== CLASS IMBALANCE QUANTIFICATION==")
counts=train["isFraud"].value_counts().rename({0:"Non-Fraud",1:"Fraud"})
percentages = (
    train["isFraud"].value_counts(normalize=True) * 100
).rename({0: "Non-Fraud", 1: "Fraud"})
imbalance_df= pd.DataFrame({"Count":counts,"Pourcentage(%)":pourcentages})
print(imbalance_df)
# Out:
# == CLASS IMBALANCE QUANTIFICATION==
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 # 1. Exact fraud cs non fraud counts and pourcentages
#       2 print("== CLASS IMBALANCE QUANTIFICATION==")
# ----> 3 counts=train["isFraud"].value_counts().rename({0:"Non-Fraud",1:"Fraud"})
#       4 percentages = (
#       5     train["isFraud"].value_counts(normalize=True) * 100
#       6 ).rename({0: "Non-Fraud", 1: "Fraud"})
#
# NameError: name 'train' is not defined
